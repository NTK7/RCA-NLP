# %%
import pandas as pd

# %%
df = pd.read_csv('./data/data.csv')
df.head()
# Out:
#                          name                             google_id  \
# 0  Barracuda Sea Food & Grill  0x3ae25ba43735a19b:0x5a042f68c0ad453
# 1  Barracuda Sea Food & Grill  0x3ae25ba43735a19b:0x5a042f68c0ad453
# 2  Barracuda Sea Food & Grill  0x3ae25ba43735a19b:0x5a042f68c0ad453
# 3  Barracuda Sea Food & Grill  0x3ae25ba43735a19b:0x5a042f68c0ad453
# 4  Barracuda Sea Food & Grill  0x3ae25ba43735a19b:0x5a042f68c0ad453
#
#                       place_id  \
# 0  ChIJm6E1N6Rb4joRU9QKjPZCoAU
# 1  ChIJm6E1N6Rb4joRU9QKjPZCoAU
# 2  ChIJm6E1N6Rb4joRU9QKjPZCoAU
# 3  ChIJm6E1N6Rb4joRU9QKjPZCoAU
# 4  ChIJm6E1N6Rb4joRU9QKjPZCoAU
#
#                                        location_link  \
# 0  https://www.google.com/maps/place/Barracuda+Se...
# 1  https://www.google.com/maps/place/Barracuda+Se...
# 2  https://www.google.com/maps/place/Barracuda+Se...
# 3  https://www.google.com/maps/place/Barracuda+Se...
# 4  https://www.google.com/maps/place/Barracuda+Se...
#
# ...

# %%
df = pd.read_csv('./data/data.csv')
df.drop(['google_id', 'place_id', 'location_link', 'reviews_link', 'reviews_per_score', 'review_id', 'author_link', 'author_title', 'author_id'], axis=1, inplace=True)
df.head()
# Out:
#                          name  rating              author_id  \
# 0  Barracuda Sea Food & Grill     4.2  117109706037751343754
# 1  Barracuda Sea Food & Grill     4.2  100926942539820654738
# 2  Barracuda Sea Food & Grill     4.2  111504476082664697328
# 3  Barracuda Sea Food & Grill     4.2  102915155204602043946
# 4  Barracuda Sea Food & Grill     4.2  116334834332067248686
#
#                                         author_image  \
# 0  https://lh3.googleusercontent.com/a/AATXAJx5Ne...
# 1  https://lh3.googleusercontent.com/a-/AOh14Gh-h...
# 2  https://lh3.googleusercontent.com/a-/AOh14Giko...
# 3  https://lh3.googleusercontent.com/a-/AOh14Gg-Z...
# 4  https://lh3.googleusercontent.com/a-/AOh14GiWg...
#
#                                          review_text  \
# 0  We had a wonderful Saturday night dinner. They...
# 1  Service was brilliant and the spicy and very d...
# 2  A nice bar and dining space in Colombo. We can...
# 3  We went there on 31st December 2021. They had ...
# ...
